# %%
#contributor:Vijaya Madasu

# %%
2+3
# Out:
# 5

# %%
5-1
# Out:
# 4

# %%
5*3
# Out:
# 15

# %%
10/2
# Out:
# 5.0

# %%
10%5
# Out:
# 0

# %%
7**4
# Out:
# 2401

# %%
s = "Hi there Sam!"
s.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %%
Name ='Vijaya'
Age=23

# %%
print('My name is {} and age is {}.'.format(Name,Age))
# Out:
# My name is Vijaya and age is 23.
